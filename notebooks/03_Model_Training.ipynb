# %%
import os

# Change to project root directory
os.chdir('..')

from src.train_models import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
# %matplotlib inline

# %%
# Train all models
results = train_all_models()
# Out:
# ==================================================
# Crop Yield Prediction - Model Training
# ==================================================
# Loaded 255 samples from data/processed/features.csv
# Features shape: (255, 67)
# Target shape: (255,)
# Number of features: 67
#
# Train set: 204 samples
# Test set: 51 samples
#
# ==================================================
# Training Random Forest Model
# ==================================================
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
#
# Best parameters: {'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_depth': 10}
#
# Random Forest (Train) Performance:
#   RMSE: 763.1676
#   R²: 0.9925
#
# Random Forest (Test) Performance:
#   RMSE: 2801.0388
#   R²: 0.9178
#
# ==================================================
# Training XGBoost Model
# ==================================================
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
#
# Best parameters: {'subsample': 0.8, 'n_estimators': 300, 'max_depth': 3, 'learning_rate': 0.2, 'colsample_bytree': 0.9}
#
# XGBoost (Train) Performance:
#   RMSE: 38.5395
#   R²: 1.0000
#
# XGBoost (Test) Performance:
#   RMSE: 3109.5193
#   R²: 0.8986
#
# ==================================================
# Training LightGBM Model
# ==================================================
# Performing hyperparameter tuning...
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
#
# Best parameters: {'subsample': 1.0, 'num_leaves': 50, 'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.2, 'colsample_bytree': 0.9}
#
# LightGBM (Train) Performance:
#   RMSE: 1682.4973
#   R²: 0.9633
#
# LightGBM (Test) Performance:
#   RMSE: 3606.1785
#   R²: 0.8637
#
# ==================================================
# Model Comparison
# ==================================================
# RANDOM_FOREST:
#   RMSE: 2801.0388
#   R²: 0.9178
# XGBOOST:
#   RMSE: 3109.5193
#   R²: 0.8986
# LIGHTGBM:
#   RMSE: 3606.1785
#   R²: 0.8637
#
# Best Model: RANDOM_FOREST (RMSE: 2801.0388)
#
# All models saved to model/ directory
